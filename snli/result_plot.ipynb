# %%
import numpy as np

import matplotlib.pyplot as plt
import seaborn

# %%
def set_plt_params():
    title_font = {'size':'30', 'color':'black', 'weight':'bold',
                  'verticalalignment':'bottom'} 
    axis_font = {'size':'30'}
    plt.figure(figsize=(10, 10))
    plt.grid(False)
    plt.axes(frameon = 0)
    #plt.tick_params(labelsize=60)
    #plt.ylim([0.76, 0.86])
    #plt.tick_params(labelsize=30)
    seaborn.set_style("whitegrid", {'grid' : False})

# %% [markdown]
# ## SICK Unlem

# %%
set_plt_params()

dimensions = [500, 400, 300, 200, 150, 100]
CBOW = [0.66, 0.55, 0.55, 0.55, 0.55, 0.54]
Skipgram = [0.67, 0.55, 0.55, 0.57, 0.56, 0.56]
Swivel = [0.67, 0.53, 0.54, 0.55, 0.56, 0.55]


plt.plot(dimensions, CBOW, linewidth=5)
plt.plot(dimensions, Skipgram, linewidth=5)
plt.plot(dimensions, Swivel, linewidth=5)

#plt.legend(loc='lower center', bbox_to_anchor=(1,1), prop={'size':30})
plt.plot()
plt.savefig('results.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## SNLI Unlem

# %%
set_plt_params()

dimensions = [500, 400, 300, 200, 150, 100]
CBOW = [0.41, 0.41, 0.41, 0.4, 0.4, 0.4]
Skipgram = [0.42, 0.42, 0.42, 0.41, 0.41, 0.41]
Swivel = [0.41, 0.41, 0.41, 0.41, 0.41, 0.4]


plt.plot(dimensions, CBOW, linewidth=5)
plt.plot(dimensions, Skipgram, linewidth=5)
plt.plot(dimensions, Swivel, linewidth=5)

#plt.legend(loc='lower center', bbox_to_anchor=(1,1), prop={'size':30})
plt.plot()
plt.savefig('results.png', bbox_inches='tight')
plt.show()
